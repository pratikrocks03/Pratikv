# %%
import requests
import json

# %%
payload={}
headers = {
  'Connection': 'keep-alive',
  'sec-ch-ua': '"Google Chrome";v="89", "Chromium";v="89", ";Not A Brand";v="99"',
  'Accept': 'application/json',
  'sec-ch-ua-mobile': '?0',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36',
  'Origin': 'https://www.target.com',
  'Sec-Fetch-Site': 'same-site',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Dest': 'empty',
  'Referer': 'https://www.target.com/s?searchTerm=clorox&Nao=72',
  'Accept-Language': 'en-US,en;q=0.9'
}

# %%
reviewID=[]
productName=[]
checkList=[]
url = "https://redsky.target.com/redsky_aggregations/v1/web/plp_search_v1?key=ff457966e64d5e877fdbad070f276d18ecec4a01&channel=WEB&count=24&default_purchasability_filter=false&include_sponsored=true&keyword=clorox&offset=12&page=%2Fs%2Fcascade&platform=desktop&pricing_store_id=3991&useragent=Mozilla%2F5.0+%28Windows+NT+10.0%3B+Win64%3B+x64%29+AppleWebKit%2F537.36+%28KHTML%2C+like+Gecko%29+Chrome%2F89.0.4389.90+Safari%2F537.36&visitor_id=0177EC29A10F02018495B2229020D579"
response = requests.request("GET", url, headers=headers, data=payload)
#print(response)
data=json.loads(response.text)
#print(data)
data=data['data']
data=data['search']
for item in data['products']:
    x=item['item']
    y=x['product_description']
    productName.append(y['title'])
    reviewID.append(item['tcin'])
for i in range(2,7,1):
    page=i*12
    
    url = "https://redsky.target.com/redsky_aggregations/v1/web/plp_search_v1?key=ff457966e64d5e877fdbad070f276d18ecec4a01&channel=WEB&count=24&default_purchasability_filter=false&include_sponsored=true&keyword=clorox&offset={}&page=%2Fs%2Fcascade&platform=desktop&pricing_store_id=3991&useragent=Mozilla%2F5.0+%28Windows+NT+10.0%3B+Win64%3B+x64%29+AppleWebKit%2F537.36+%28KHTML%2C+like+Gecko%29+Chrome%2F89.0.4389.90+Safari%2F537.36&visitor_id=0177EC29A10F02018495B2229020D579".format(page)

    
    response = requests.request("GET", url, headers=headers, data=payload)
    #print(response)
    data=json.loads(response.text)
    #print(data)
    data=data['data']
    data=data['search']
    for item in data['products']:
        x=item['item']
        y=x['product_description']
        productName.append(y['title'])
        reviewID.append(item['tcin'])

# %%
for i in reviewID:
    print(i)
# Out:
# 12992464
# 80314940
# 75664026
# 77787194
# 53133307
# 81428796
# 77787195
# 77787193
# 81579184
# 12992360
# 77787199
# 77787201
# 78314373
# 78314367
# 52977197
# 77787192
# 81579186
# 77787200
# 81579192
# 81428787
# 81428788
# 81428795
# 81428796
# 15804793
# 84230737
# 13025566
# 13025049
# 77787192
# 81579186
# 77787194
# 77787200
# 81579192
# 13028422
# 81428787
# 81428788
# 14710160
# 81428795
# 81428796
# 81579192
# 15804793
# 84230737
# 13025566
# 13025049
# 75666304
# 13028043
# 14710160
# 14710162
# 84230736
# 50501481
# 81618505
# 84207121
# 84230740
# 84207124
# 84230742
# 84207119
# 75666304
# 13028043
# 77787194
# 14710160
# 14710162
# 13028422
# 84230736
# 50501481
# 14710160
# 81618505
# 84207121
# 81579192
# 84230740
# 84207124
# 84230742
# 84207119
# 84207120
# 81579184
# 12992471
# 13793923
# 14763602
# 13025048
# 13793925
# 17099224
# 13601825
# 78362269
# 13793819
# 53381078
# 84207120
# 81579184
# 77787193
# 12992471
# 13793923
# 13025050
# 14763602
# ...

# %%
len(reviewID)
# Out:
# 167

# %%
for i in productName:
    print(i)
# Out:
# Clorox Bleach Free Disinfecting Wipes Value Pack - 105ct/3pk
# Clorox Disinfecting Wipes - To Go Citrus - 9ct
# Clorox Fabric Sanitizer Spray, Color-Safe Laundry Sanitizer - 24oz
# Clorox Splash-Less Liquid Bleach - Crisp Lemon - 77oz
# Clorox Disinfecting Wipes - Fresh Scent - 75ct
# Clorox Disinfecting Mopping Cloth - Rain Clean - 12ct
# Clorox Splash-Less Liquid Bleach - Regular - 40oz
# Clorox Disinfecting Bleach - Regular - 121oz
# Clorox Clinical Soft Surface &#38; Bio-Stain Cleaner - 32 fl oz
# Clorox Disinfecting Wipes Bleach Free Cleaning Wipes - Fresh - 9ct
# Clorox Splash-Less Liquid Bleach - Fresh Meadow - 77oz
# Clorox Splash-Less Liquid Bleach - Regular - 117oz
# Clorox Compostable Wipes - Lemon - 75ct
# Clorox Compostable Wipes - Free &#38; Clear - 75ct
# Clorox ColorLoad Non-Chlorine Bleach - 116oz
# Clorox Splash-Less Liquid Bleach - Clean Linen - 117oz
# Clorox Clinical Germicidal Wipes - 75ct
# Clorox Disinfecting Bleach - Regular - 11oz
# ...

# %%
len(productName)
# Out:
# 167

# %%
import pandas as pd

# %%
df3=pd.DataFrame()

# %%
nameOfProduct=[]
productTitle=[]
productReview=[]
reviewDate=[]
productRating=[]
review_ID=[]
uniqueID=[]

# %%
for p,q in zip(productName,reviewID):
    for page in range(0,4):
        
        id_review=q
        url = "https://r2d2.target.com/ggc/reviews/v1/reviews?reviewType=PRODUCT&key=c6b68aaef0eac4df4931aae70500b7056531cb37&reviewedId={}&sortBy=most_recent&page={}&size=8&hasOnlyPhotos=false&ratingFilter=&verifiedOnly=false".format(id_review,page)

        payload={}
        headers = {
          'Connection': 'keep-alive',
          'sec-ch-ua': '"Google Chrome";v="89", "Chromium";v="89", ";Not A Brand";v="99"',
          'Accept': 'application/json',
          'sec-ch-ua-mobile': '?0',
          'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36',
          'Origin': 'https://www.target.com',
          'Sec-Fetch-Site': 'same-site',
          'Sec-Fetch-Mode': 'cors',
          'Sec-Fetch-Dest': 'empty',
          'Referer': 'https://www.target.com/p/clorox-fresh-scent-disinfecting-wipes-fresh/-/A-79389925?preselect=12992466',
          'Accept-Language': 'en-US,en;q=0.9'
        }

        response = requests.request("GET", url, headers=headers, data=payload)
        data=json.loads(response.text)
        #print(data)
        for item in data['results']:
            
            
            #print(item['title'])
            try:
                nameOfProduct.append(p)
                productTitle.append(item['title'])
                productReview.append(item['text'])
                reviewDate.append(item['submitted_at'])
                productRating.append(item['Rating'])
                uniqueID.append(item['id'])
                review_ID.append(q)
                df2=pd.DataFrame([[uniqueID,nameOfProduct,review_ID,reviewDate,productTitle,productReview,productRating]],columns=['Review ID','Product Name','ID','Date','Title','Review','Rating'])
                df3=df3.append(df2,ignore_index=True)
                nameOfProduct=[] 
                productTitle=[]
                productReview=[]
                reviewDate=[]
                productRating=[]
                review_ID=[]
                uniqueID=[]
                df2=[]
            except:
                continue

# %%
df3
# Out:
#                                    Review ID  \
# 0     [bfce1c65-4a38-4890-be7c-d08a658c196d]
# 1     [6d430af8-8825-4b19-b142-4dca96bd8a15]
# 2     [e5a398dc-3b04-4340-b389-bd744ed0a6f4]
# 3     [e7078f9f-94c8-4209-b44a-701e5e3c5622]
# 4     [c0ad4ef6-2fba-47d3-b83b-8399da4c4ba4]
# ...                                      ...
# 4317  [e8f69be3-8f04-4db5-9d2f-deb92bdf2ec8]
# 4318  [1425505a-d16f-4008-9b8c-361f29f18115]
# 4319  [76fc17b7-e4c4-42b9-9332-5ebe525af8be]
# 4320  [9261ed4a-981c-4aeb-8f56-cd61284371b9]
# 4321  [a70e4f74-32d1-4aa1-8597-c885a4e35b4c]
#
#                                            Product Name          ID  \
# 0     [Clorox Bleach Free Disinfecting Wipes Value P...  [12992464]
# 1     [Clorox Bleach Free Disinfecting Wipes Value P...  [12992464]
# 2     [Clorox Bleach Free Disinfecting Wipes Value P...  [12992464]
# 3     [Clorox Bleach Free Disinfecting Wipes Value P...  [12992464]
# 4     [Clorox Bleach Free Disinfecting Wipes Value P...  [12992464]
# ...

# %%
df3=df3.drop_duplicates('Review ID')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-d1b69ece0435> in <module>
# ----> 1 df3=df3.drop_duplicates('Review ID')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    5106
#    5107         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 5108         duplicated = self.duplicated(subset, keep=keep)
#    5109
#    5110         result = self[-duplicated]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in duplicated(self, subset, keep)
#    5245
#    5246         vals = (col.values for name, col in self.items() if name in subset)
# -> 5247         labels, shape = map(list, zip(*map(f, vals)))
#    5248
#    5249         ids = get_group_index(labels, shape, sort=False, xnull=False)
#
# ...

# %%
df3.to_excel('TargetCloroxWebscraping4.xlsx')
