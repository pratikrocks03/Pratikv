# %% [markdown]
# # ABC is an online content sharing platform that enables users to create, upload and share the content in the form of videos. It includes videos from different genres like entertainment, education, sports, technology and so on. The maximum duration of video is 10 minutes.
#
# # Users can like, comment and share the videos on the platform.
#
# # Based on the user’s interaction with the videos, engagement score is assigned to the video with respect to each user. Engagement score defines how engaging the content of the video is.
#
# # Understanding the engagement score of the video improves the user’s interaction with the platform. It defines the type of content that is appealing to the user and engages the larger audience.

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the Dataset

# %%
df=pd.read_csv('engagement_train.csv')
df.head()
# Out:
#    row_id  user_id  category_id  video_id  age  gender            profession  \
# 0       1    19990           37       128   24    Male               Student
# 1       2     5304           32       132   14  Female               Student
# 2       3     1840           12        24   19    Male               Student
# 3       4    12597           23       112   19    Male               Student
# 4       5    13626           23       112   27    Male  Working Professional
#
#    followers  views  engagement_score
# 0        180   1000              4.33
# 1        330    714              1.79
# 2        180    138              4.35
# 3        220    613              3.77
# 4        220    613              3.13

# %% [markdown]
# # Analyzing the patterns of the Dataset

# %%
# Checking shape
df.shape
# Out:
# (89197, 10)

# %% [markdown]
# 89197 rows and 10 columns are present in the dataset.

# %%
# checking datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89197 entries, 0 to 89196
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   row_id            89197 non-null  int64
#  1   user_id           89197 non-null  int64
#  2   category_id       89197 non-null  int64
#  3   video_id          89197 non-null  int64
#  4   age               89197 non-null  int64
#  5   gender            89197 non-null  object
#  6   profession        89197 non-null  object
#  7   followers         89197 non-null  int64
#  8   views             89197 non-null  int64
#  9   engagement_score  89197 non-null  float64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 6.8+ MB

# %% [markdown]
# 1 float datatype, 7 integer datatype and 2 object datatype columns are present in the dataset.

# %%
# Checking Null values
df.isnull().sum()
# Out:
# row_id              0
# user_id             0
# category_id         0
# video_id            0
# age                 0
# gender              0
# profession          0
# followers           0
# views               0
# engagement_score    0
# dtype: int64

# %% [markdown]
# Null Values are not present in the dataset.

# %%
# Removing unwanted column that is row_id
del df['row_id']
df.shape
# Out:
# (89197, 9)

# %% [markdown]
# Now 89197 rows and 9 columns are present.

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS for Nominal data

# %%
df.columns
# Out:
# Index(['user_id', 'category_id', 'video_id', 'age', 'gender', 'profession',
#        'followers', 'views', 'engagement_score'],
#       dtype='object')

# %%
ax=sns.countplot(x='gender',data=df)
print(df['gender'].value_counts())
# Out:
# Male      52397
# Female    36800
# Name: gender, dtype: int64

# %% [markdown]
# Number of Male is more than the Female. The count of the Male is 52397 and the count of the female is 36800.

# %%
ax=sns.countplot(x='profession',data=df)
print(df['profession'].value_counts())
# Out:
# Student                 44638
# Other                   26840
# Working Professional    17719
# Name: profession, dtype: int64

# %% [markdown]
# Students are more than the Working Professional and others.

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS for continuous data

# %%
df.columns
# Out:
# Index(['user_id', 'category_id', 'video_id', 'age', 'gender', 'profession',
#        'followers', 'views', 'engagement_score'],
#       dtype='object')

# %%
sns.distplot(df['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# Age is in range from 10 to 50 and most of the users are range from 10 to 30.

# %%
sns.distplot(df['followers'])
# Out:
# <AxesSubplot:xlabel='followers', ylabel='Density'>

# %% [markdown]
# followers are varrying and most of the followers are between 200 to 250.

# %%
sns.distplot(df['views'])
# Out:
# <AxesSubplot:xlabel='views', ylabel='Density'>

# %% [markdown]
# views are varrying and most of the views are form 600 to 800.

# %%
sns.distplot(df['engagement_score'])
# Out:
# <AxesSubplot:xlabel='engagement_score', ylabel='Density'>

# %% [markdown]
# Engagement score right skewed and ranges from 1 to 5.

# %% [markdown]
# # Visualization using scatter plot

# %%
df.columns
# Out:
# Index(['user_id', 'category_id', 'video_id', 'age', 'gender', 'profession',
#        'followers', 'views', 'engagement_score'],
#       dtype='object')

# %%
plt.figure(figsize=[10,6])
plt.title(' comparison between age  and engagement_score')
sns.scatterplot(df['age'], df['engagement_score'],hue=df['gender'])
# Out:
# <AxesSubplot:title={'center':' comparison between age  and gender'}, xlabel='age', ylabel='engagement_score'>

# %% [markdown]
# Scatter plot is showing that female engagement score is more than the male on the basis of age between 10 to approx 50.

# %%
plt.figure(figsize=[10,6])
plt.title(' comparison between age  and engagement_score')
sns.scatterplot(df['age'], df['engagement_score'],hue=df['profession'])
# Out:
# <AxesSubplot:title={'center':' comparison between age  and engagement_score'}, xlabel='age', ylabel='engagement_score'>

# %% [markdown]
# Scatter plot is showing that Number of students are more between age group of 10 to approx 30 with the engagement score above 2.

# %%
plt.figure(figsize=[10,6])
plt.title(' comparison between age  and profession')
sns.scatterplot(df['age'], df['profession'],hue=df['gender'])
# Out:
# <AxesSubplot:title={'center':' comparison between age  and engagement_score'}, xlabel='age', ylabel='profession'>

# %% [markdown]
# Student are from age group of 10 to 30 with almost equally distributed on the basis of gender.
#
# most of theworking profession are from age group of 20 to approx 60 with more number of males than female.
#
# other are from age group of 20 to 50 with more number of females than male.

# %% [markdown]
# # CHECKING OUTLIERS

# %%
df.plot(kind='box',subplots=True,layout=(4,7),figsize=(15,10))
# Out:
# user_id                AxesSubplot(0.125,0.71587;0.0945122x0.16413)
# category_id         AxesSubplot(0.238415,0.71587;0.0945122x0.16413)
# video_id            AxesSubplot(0.351829,0.71587;0.0945122x0.16413)
# age                 AxesSubplot(0.465244,0.71587;0.0945122x0.16413)
# followers           AxesSubplot(0.578659,0.71587;0.0945122x0.16413)
# views               AxesSubplot(0.692073,0.71587;0.0945122x0.16413)
# engagement_score    AxesSubplot(0.805488,0.71587;0.0945122x0.16413)
# dtype: object

# %% [markdown]
# Outliers are present in the age column but it will not removed because it may be important for the prediction and outliers are also present in engagement score column but engagement score is the target column so outlier will not treated on the target column.

# %% [markdown]
# # Encoding The gender  and profession column

# %%
# male as 0 and female as 1
df.replace({'Male':0, 'Female':1},inplace=True)

# student as 0, working professional as 1 and other as 2
df.replace({'Student':0,'Working Professional':1,'Other':2},inplace=True)

# %%
df
# Out:
#        user_id  category_id  video_id  age  gender  profession  followers  \
# 0        19990           37       128   24       0           0        180
# 1         5304           32       132   14       1           0        330
# 2         1840           12        24   19       0           0        180
# 3        12597           23       112   19       0           0        220
# 4        13626           23       112   27       0           1        220
# ...        ...          ...       ...  ...     ...         ...        ...
# 89192    23996           15        32   25       0           2        340
# 89193    20466           20        47   31       0           2        240
# 89194    13655           16        97   25       0           0        270
# 89195    24840            9        18   35       0           1        230
# 89196    27183           25       150   13       0           0        240
#
#        views  engagement_score
# 0       1000              4.33
# ...

# %% [markdown]
# Object column is now encoded in numeric column.

# %% [markdown]
# # Statistical Summary

# %%
df.describe()
# Out:
#             user_id   category_id      video_id           age        gender  \
# count  89197.000000  89197.000000  89197.000000  89197.000000  89197.000000
# mean   13881.909806     18.323733     77.715383     24.848616      0.412570
# std     8005.582771     11.675154     48.469656      8.955535      0.492299
# min        1.000000      1.000000      1.000000     10.000000      0.000000
# 25%     6945.000000      8.000000     34.000000     18.000000      0.000000
# 50%    13892.000000     16.000000     76.000000     23.000000      0.000000
# 75%    20819.000000     26.000000    120.000000     32.000000      1.000000
# max    27734.000000     47.000000    175.000000     68.000000      1.000000
#
#          profession     followers         views  engagement_score
# count  89197.000000  89197.000000  89197.000000      89197.000000
# mean       0.800464    252.460172    502.980268          3.487797
# std        0.872665     46.094468    268.569482          0.863498
# ...

# %% [markdown]
# Count is same in the every column.
#
# There is not much difference between mean and median in any of the columns.
#
# There is not much difference between 75th percentile and maximum in the columns.

# %% [markdown]
# # Checking Correlateion

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Most of the columns are negatively correlated with engagement_score column.
#
# video_id postively correlated with category_id.
#
# Profession is positively correlated with age.

# %% [markdown]
# # Splitting the dataset into x and y

# %%
x=df.drop('engagement_score',axis=1)
y=df['engagement_score']

# %%
x.shape
# Out:
# (89197, 8)

# %%
y.shape
# Out:
# (89197,)

# %% [markdown]
# # Lets bring all features to a common scale

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

x=sc.fit_transform(df)

x=pd.DataFrame(x,columns=df.columns)

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=.20, random_state=43)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (71357, 9)
# (17840, 9)
# (71357,)
# (17840,)

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.model_selection import cross_val_score

# %%
# linear Regression
lr=LinearRegression()
lr.fit(x_train,y_train)
pred_y=lr.predict(x_test)

print('r2 score',r2_score(y_test,pred_y))

print('error')
print('mean absolute error',mean_absolute_error(y_test,pred_y))
print('mean squared error',mean_squared_error(y_test,pred_y))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,pred_y)))
# Out:
# r2 score 1.0
# error
# mean absolute error 8.071228818579309e-16
# mean squared error 9.697727796426159e-31
# root mean squared error 9.84770419764229e-16

# %%
# Cross validation Linear Regression

score=cross_val_score(lr,x,y,cv=10)
print('cv score',np.mean(score))
# Out:
# cv score 1.0

# %% [markdown]
# Both r2 score and cv score is 100% so it is overfiited.

# %%
# for Lasso

ls=Lasso()

ls.fit(x_train,y_train)
pred_y=ls.predict(x_test)
print('r2 score',r2_score(y_test,pred_y))

print('error')
print('mean absolute error', mean_absolute_error(y_test,pred_y))
print('mean squared error', mean_squared_error(y_test,pred_y))

print('root mean squared error', np.sqrt(mean_squared_error(y_test,pred_y)))
# Out:
# r2 score -6.791742765921427e-05
# error
# mean absolute error 0.6932817691813746
# mean squared error 0.7484166624900856
# root mean squared error 0.8651107804727008

# %%
# cross validation Lasso
score=cross_val_score(ls,x,y,cv=10)
print('cv score',np.mean(score))
# Out:
# cv score -9.432988923814278e-05

# %% [markdown]
# r2 score is giving -6.79 and cv score is giving -9.43.

# %%
# for Ridge
rd=Ridge()
rd.fit(x_train,y_train)
pred_y=rd.predict(x_test)
print('r2 score',r2_score(y_test,pred_y))

print('error')
print('mean absolute error',mean_absolute_error(y_test,pred_y))
print('mean squared error',mean_squared_error(y_test,pred_y))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,pred_y)))
# Out:
# r2 score 0.999999999739443
# error
# mean absolute error 1.079127951453577e-05
# mean squared error 1.9499197481444183e-10
# root mean squared error 1.396395269307519e-05

# %%
# Cross validation Ridge
score=cross_val_score(rd,x,y,cv=10)
print('cv score',np.mean(score))
# Out:
# cv score 0.9999999997956122

# %% [markdown]
# r2 score is 99% and cv score is 99%.

# %%
# for elasticnet
en=ElasticNet()
en.fit(x_train,y_train)
pred_y=en.predict(x_test)
print('r2 score',r2_score(y_test,pred_y))

print('error')
print('mean absolute error',mean_absolute_error(y_test,pred_y))
print('mean squared error',mean_squared_error(y_test,pred_y))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,pred_y)))
# Out:
# r2 score 0.48183763874308294
# error
# mean absolute error 0.49903150437102717
# mean squared error 0.3877750083588057
# root mean squared error 0.6227158327510275

# %%
# Cross validation Ridge
score=cross_val_score(en,x,y,cv=10)
print('cv score',np.mean(score))
# Out:
# cv score 0.482465458913509

# %% [markdown]
# r2 score is 48% and cv score is 48%.

# %% [markdown]
# # Hyper Parameter Tuning RandomForest Regreesor using Grid Search Cv

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# %%
parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log'],'max_depth':[0,5]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)

# %%
rf=RandomForestRegressor(criterion='mse',max_features='auto',max_depth=5)
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_y=rf.predict(x_test)

rfs=r2_score(y_test,pred_y)
print('r2 score',rfs*100)

rfscore=cross_val_score(rf,x,y,cv=5)
rfc=rfscore.mean()
print('cv score',rfc*100)
