# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading the Dataset

# %%
df=pd.read_csv("ailerons_(mechademy).csv")
df.head()
# Out:
#    climbRate  Sgz     p     q  curPitch  curRoll  absRoll  diffClb  \
# 0          2  -56 -0.33 -0.09      0.90      0.2      -11       12
# 1        470  -39  0.02  0.12      0.39     -0.6      -12        8
# 2        165    4  0.14  0.14      0.78      0.4      -11       -9
# 3       -113    5 -0.12  0.11      1.06      0.6      -10       -7
# 4       -411  -21 -0.17  0.07      1.33     -0.6      -11        0
#
#    diffRollRate  diffDiffClb  ...  diffSeTime8  diffSeTime9  diffSeTime10  \
# 0         0.004         -0.1  ...          0.0          0.0           0.0
# 1         0.009         -1.6  ...          0.0          0.0           0.0
# 2        -0.003         -0.2  ...          0.0          0.0           0.0
# 3        -0.008          0.0  ...          0.0          0.0           0.0
# 4         0.002          0.1  ...          0.0          0.0           0.0
#
#    diffSeTime11  diffSeTime12  diffSeTime13  diffSeTime14  alpha     Se  \
# 0           0.0           0.0         0.000           0.0    0.9  0.032
# 1           0.0           0.0         0.000           0.0    0.9  0.034
# 2           0.0           0.0         0.000           0.0    1.0  0.034
# 3           0.0           0.0         0.000           0.0    0.9  0.033
# 4           0.0           0.0        -0.002           0.0    0.9  0.032
#
#      goal
# 0 -0.0009
# 1 -0.0011
# 2 -0.0012
# 3 -0.0011
# 4 -0.0008
#
# [5 rows x 41 columns]

# %% [markdown]
# top 5 heads of the datasets.

# %%
df.tail()
# Out:
#        climbRate  Sgz     p     q  curPitch  curRoll  absRoll  diffClb  \
# 12245        448   39  0.21  0.05      0.14     -0.5       -8       -4
# 12246        179   64  0.06  0.17      0.41      0.5       -8       -9
# 12247         65   66 -0.03  0.14      0.54      0.5       -7      -17
# 12248        -22   66 -0.08  0.23      0.61      0.5       -8      -15
# 12249        -59   47 -0.04  0.07      0.61     -0.7       -9       -7
#
#        diffRollRate  diffDiffClb  ...  diffSeTime8  diffSeTime9  diffSeTime10  \
# 12245         0.009         -0.1  ...          0.0        0.000           0.0
# 12246        -0.010         -0.6  ...          0.0        0.000           0.0
# 12247        -0.010          0.4  ...          0.0        0.001           0.0
# 12248        -0.010         -0.6  ...          0.0        0.000           0.0
# 12249         0.004          0.2  ...          0.0        0.000           0.0
#
#        diffSeTime11  diffSeTime12  diffSeTime13  diffSeTime14  alpha     Se  \
# 12245           0.0           0.0           0.0           0.0    0.5  0.019
# 12246           0.0           0.0           0.0           0.0    0.6  0.021
# 12247           0.0           0.0           0.0           0.0    0.6  0.021
# 12248           0.0           0.0           0.0           0.0    0.6  0.022
# 12249           0.0           0.0           0.0           0.0    0.6  0.020
#
#          goal
# 12245 -0.0007
# 12246 -0.0008
# 12247 -0.0007
# 12248 -0.0006
# 12249 -0.0004
#
# [5 rows x 41 columns]

# %% [markdown]
# Bottom 5 of the dataset.

# %% [markdown]
# # Analyzing the Patterns of the Dataset

# %%
# Checking shape
df.shape
# Out:
# (12250, 41)

# %% [markdown]
# 12250 rows and 41 columns are present in the dataset.

# %%
# Checking Datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12250 entries, 0 to 12249
# Data columns (total 41 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   climbRate     12250 non-null  int64
#  1   Sgz           12250 non-null  int64
#  2   p             12250 non-null  float64
#  3   q             12250 non-null  float64
#  4   curPitch      12250 non-null  float64
#  5   curRoll       12250 non-null  float64
#  6   absRoll       12250 non-null  int64
#  7   diffClb       12250 non-null  int64
#  8   diffRollRate  12250 non-null  float64
#  9   diffDiffClb   12250 non-null  float64
#  10  SeTime1       12250 non-null  float64
#  11  SeTime2       12250 non-null  float64
#  12  SeTime3       12250 non-null  float64
#  13  SeTime4       12250 non-null  float64
#  14  SeTime5       12250 non-null  float64
#  15  SeTime6       12250 non-null  float64
#  16  SeTime7       12250 non-null  float64
#  17  SeTime8       12250 non-null  float64
#  18  SeTime9       12250 non-null  float64
#  19  SeTime10      12250 non-null  float64
#  20  SeTime11      12250 non-null  float64
#  21  SeTime12      12250 non-null  float64
#  22  SeTime13      12250 non-null  float64
#  23  SeTime14      12250 non-null  float64
#  24  diffSeTime1   12250 non-null  float64
#  25  diffSeTime2   12250 non-null  float64
#  26  diffSeTime3   12250 non-null  float64
#  27  diffSeTime4   12250 non-null  float64
#  28  diffSeTime5   12250 non-null  float64
#  29  diffSeTime6   12250 non-null  float64
#  30  diffSeTime7   12250 non-null  float64
#  31  diffSeTime8   12250 non-null  float64
#  32  diffSeTime9   12250 non-null  float64
#  33  diffSeTime10  12250 non-null  float64
#  34  diffSeTime11  12250 non-null  float64
#  35  diffSeTime12  12250 non-null  float64
#  36  diffSeTime13  12250 non-null  float64
#  37  diffSeTime14  12250 non-null  float64
#  38  alpha         12250 non-null  float64
#  39  Se            12250 non-null  float64
#  40  goal          12250 non-null  float64
# dtypes: float64(37), int64(4)
# memory usage: 3.8 MB

# %% [markdown]
# 37 float datatype columns and 4 integer datatype columns are present in the dataset.

# %%
# Checking null values
df.isnull().sum()
# Out:
# climbRate       0
# Sgz             0
# p               0
# q               0
# curPitch        0
# curRoll         0
# absRoll         0
# diffClb         0
# diffRollRate    0
# diffDiffClb     0
# SeTime1         0
# SeTime2         0
# SeTime3         0
# SeTime4         0
# SeTime5         0
# SeTime6         0
# SeTime7         0
# SeTime8         0
# SeTime9         0
# SeTime10        0
# SeTime11        0
# SeTime12        0
# SeTime13        0
# SeTime14        0
# diffSeTime1     0
# diffSeTime2     0
# diffSeTime3     0
# diffSeTime4     0
# diffSeTime5     0
# diffSeTime6     0
# diffSeTime7     0
# diffSeTime8     0
# diffSeTime9     0
# diffSeTime10    0
# diffSeTime11    0
# diffSeTime12    0
# diffSeTime13    0
# diffSeTime14    0
# alpha           0
# Se              0
# goal            0
# dtype: int64

# %% [markdown]
# Null values are not present in the dataset.

# %%
# Checking columns
df.columns
# Out:
# Index(['climbRate', 'Sgz', 'p', 'q', 'curPitch', 'curRoll', 'absRoll',
#        'diffClb', 'diffRollRate', 'diffDiffClb', 'SeTime1', 'SeTime2',
#        'SeTime3', 'SeTime4', 'SeTime5', 'SeTime6', 'SeTime7', 'SeTime8',
#        'SeTime9', 'SeTime10', 'SeTime11', 'SeTime12', 'SeTime13', 'SeTime14',
#        'diffSeTime1', 'diffSeTime2', 'diffSeTime3', 'diffSeTime4',
#        'diffSeTime5', 'diffSeTime6', 'diffSeTime7', 'diffSeTime8',
#        'diffSeTime9', 'diffSeTime10', 'diffSeTime11', 'diffSeTime12',
#        'diffSeTime13', 'diffSeTime14', 'alpha', 'Se', 'goal'],
#       dtype='object')

# %%
# checking unique values in some of the columns that seems to be nominal or single value 
print(pd.unique(df[['SeTime1', 'SeTime2',
       'SeTime3', 'SeTime4', 'SeTime5', 'SeTime6', 'SeTime7', 'SeTime8',
       'SeTime9', 'SeTime10', 'SeTime11', 'SeTime12', 'SeTime13', 'SeTime14']].values.ravel()))

print("\n")

print(pd.unique(df[['diffSeTime1', 'diffSeTime2', 'diffSeTime3', 'diffSeTime4',
       'diffSeTime5', 'diffSeTime6', 'diffSeTime7', 'diffSeTime8',
       'diffSeTime9', 'diffSeTime10', 'diffSeTime11', 'diffSeTime12',
       'diffSeTime13', 'diffSeTime14']].values.ravel()))
# Out:
# [0.032 0.034 0.033 0.03  0.028 0.029 0.027 0.026 0.024 0.025 0.022 0.02
#  0.023 0.021 0.018 0.019 0.017 0.016 0.031 0.014 0.015 0.035 0.036 0.051
#  0.049 0.06  0.056 0.059 0.061 0.057 0.045 0.04  0.047 0.044 0.048 0.053
#  0.052 0.042 0.039 0.046 0.043 0.041 0.038 0.037 0.012 0.013 0.055 0.058
#  0.062 0.065 0.073 0.071 0.069 0.067 0.078 0.076 0.066 0.068 0.05  0.054
#  0.074 0.064 0.063]
#
#
# [ 0.    -0.002 -0.001  0.001  0.002 -0.003  0.003 -0.004  0.004  0.006
#  -0.006  0.007 -0.005  0.005 -0.008]

# %% [markdown]
# We can see in columns from diffSeTime1 to diffSeTime12 very little values are found, So we have to drop them for further process.

# %%
# Dropping Unnecessary columns
data=df.drop(['diffSeTime1', 'diffSeTime2', 'diffSeTime3', 'diffSeTime4',
       'diffSeTime5', 'diffSeTime6', 'diffSeTime7', 'diffSeTime8',
       'diffSeTime9', 'diffSeTime10', 'diffSeTime11', 'diffSeTime12',
       'diffSeTime13', 'diffSeTime14'],axis =1 )

# %%
# Checking shape again
data.shape
# Out:
# (12250, 27)

# %% [markdown]
# Now we have 12250 rows and 27 columns are present in the dataset.

# %% [markdown]
# # Exploratory Data Analysis(Distribution)

# %%
data.columns
# Out:
# Index(['climbRate', 'Sgz', 'p', 'q', 'curPitch', 'curRoll', 'absRoll',
#        'diffClb', 'diffRollRate', 'diffDiffClb', 'SeTime1', 'SeTime2',
#        'SeTime3', 'SeTime4', 'SeTime5', 'SeTime6', 'SeTime7', 'SeTime8',
#        'SeTime9', 'SeTime10', 'SeTime11', 'SeTime12', 'SeTime13', 'SeTime14',
#        'alpha', 'Se', 'goal'],
#       dtype='object')

# %%
# climbRate
sns.distplot(df['climbRate'],kde=True)
# Out:
# <AxesSubplot:xlabel='climbRate', ylabel='Density'>

# %% [markdown]
# climbRate column is looking normally distributed in the range from -1000 to 1000.

# %%
# Sgz
sns.distplot(df['Sgz'],kde=True)
# Out:
# <AxesSubplot:xlabel='Sgz', ylabel='Density'>

# %% [markdown]
# Sgz column is looking normally distributed and in range from -100 to 100.

# %%
# p
sns.distplot(df['p'],kde=True)
# Out:
# <AxesSubplot:xlabel='p', ylabel='Density'>

# %% [markdown]
# p column is showing somehow normally distribution and in ranges from -1.0 to 1.0.

# %%
# q
sns.distplot(df['q'],kde=True)
# Out:
# <AxesSubplot:xlabel='q', ylabel='Density'>

# %% [markdown]
# q column is showing normal distribution within the range from -0.4 to 0.4(maximum values.)

# %%
# curPitch
sns.distplot(df['curPitch'],kde=True)
# Out:
# <AxesSubplot:xlabel='curPitch', ylabel='Density'>

# %% [markdown]
# curPitch column is looking somehow normally distributed and in range from -0.5.

# %%
# curRoll
sns.distplot(df['curRoll'],kde=True)
# Out:
# <AxesSubplot:xlabel='curRoll', ylabel='Density'>

# %% [markdown]
# curRoll column is with less values and looking normal and in ranges from -3 to 3.

# %%
# absRoll
sns.distplot(df['absRoll'],kde=True)
# Out:
# <AxesSubplot:xlabel='absRoll', ylabel='Density'>

# %% [markdown]
# absRoll column is varying and and values are negative.

# %%
# diffClb
sns.distplot(df['diffClb'],kde=True)
# Out:
# <AxesSubplot:xlabel='diffClb', ylabel='Density'>

# %% [markdown]
# diffClb column is looking normally distributed and  in ranges from -40 to 40.

# %%
# diffRollRate
sns.distplot(df['diffRollRate'],kde=True)
# Out:
# <AxesSubplot:xlabel='diffRollRate', ylabel='Density'>

# %% [markdown]
# diffRollRate column is looking somehow normally distributed.

# %%
# diffDiffClb
sns.distplot(df['diffDiffClb'],kde=True)
# Out:
# <AxesSubplot:xlabel='diffDiffClb', ylabel='Density'>

# %% [markdown]
# In diffDiffClb column most of the values are from -5 to 5.

# %%
# SeTime1
sns.distplot(df['SeTime1'],kde=True)
# Out:
# <AxesSubplot:xlabel='SeTime1', ylabel='Density'>

# %% [markdown]
# SeTime1 column is not looking normally distributed it is right skewed.

# %%
# SeTime2
sns.distplot(df['SeTime2'],kde=True)
# Out:
# <AxesSubplot:xlabel='SeTime2', ylabel='Density'>

# %% [markdown]
# SeTime2 column is not looking normally distributed it is right skewed

# %%
# SeTime3
sns.distplot(df['SeTime3'],kde=True)
# Out:
# <AxesSubplot:xlabel='SeTime3', ylabel='Density'>

# %% [markdown]
# SeTime3 column is not looking normally distributed it is right skewed.

# %%
# SeTime4
sns.distplot(df['SeTime4'],kde=True)
# Out:
# <AxesSubplot:xlabel='SeTime4', ylabel='Density'>

# %% [markdown]
# SeTime4 column is not looking normally distributed it is right skewed.

# %%
# SeTime5
sns.distplot(df['SeTime5'],kde=True)
# Out:
# <AxesSubplot:xlabel='SeTime5', ylabel='Density'>

# %% [markdown]
# SeTime5 column is not looking normally distributed it is right skewed.

# %%
#SeTime6
sns.distplot(df['SeTime6'],kde=True)
# Out:
# <AxesSubplot:xlabel='SeTime6', ylabel='Density'>

# %% [markdown]
# SeTime6 column is not looking normally distributed it is right skewed.

# %%
#SeTime7
sns.distplot(df['SeTime7'],kde=True)
# Out:
# <AxesSubplot:xlabel='SeTime7', ylabel='Density'>

# %% [markdown]
# SeTime7 column is not looking normally distributed it is right skewed.

# %%
#SeTime8
sns.distplot(df['SeTime8'],kde=True)
# Out:
# <AxesSubplot:xlabel='SeTime8', ylabel='Density'>

# %% [markdown]
# SeTime8 column is not looking normally distributed it is right skewed.

# %%
#SeTime9
sns.distplot(df['SeTime9'],kde=True)
# Out:
# <AxesSubplot:xlabel='SeTime9', ylabel='Density'>

# %% [markdown]
# SeTime9 column is not looking normally distributed it is right skewed.

# %%
#SeTime10
sns.distplot(df['SeTime10'],kde=True)
# Out:
# <AxesSubplot:xlabel='SeTime10', ylabel='Density'>

# %% [markdown]
# SeTime10 column is not looking normally distributed it is right skewed.

# %%
#SeTime11
sns.distplot(df['SeTime11'],kde=True)
# Out:
# <AxesSubplot:xlabel='SeTime11', ylabel='Density'>

# %% [markdown]
# SeTime11 column is not looking normally distributed it is right skewed.

# %%
#SeTime12
sns.distplot(df['SeTime12'],kde=True)
# Out:
# <AxesSubplot:xlabel='SeTime12', ylabel='Density'>

# %% [markdown]
# SeTime12 column is not looking normally distributed it is right skewed.

# %%
#SeTime13
sns.distplot(df['SeTime13'],kde=True)
# Out:
# <AxesSubplot:xlabel='SeTime13', ylabel='Density'>

# %% [markdown]
# SeTime13 column is not looking normally distributed it is right skewed.

# %%
#SeTime14
sns.distplot(df['SeTime14'],kde=True)
# Out:
# <AxesSubplot:xlabel='SeTime14', ylabel='Density'>

# %% [markdown]
# SeTime14 column is not looking normally distributed it is right skewed.

# %%
#alpha
sns.distplot(df['alpha'],kde=True)
# Out:
# <AxesSubplot:xlabel='alpha', ylabel='Density'>

# %% [markdown]
# alpha column is showing variation from 0.25 to 1.25.

# %%
#Se
sns.distplot(df['Se'],kde=True)
# Out:
# <AxesSubplot:xlabel='Se', ylabel='Density'>

# %% [markdown]
# Se column is not looking normally ditributed it is bit right skewed.

# %%
#goal
sns.distplot(df['goal'],kde=True)
# Out:
# <AxesSubplot:xlabel='goal', ylabel='Density'>

# %% [markdown]
# goal column is the target column.

# %% [markdown]
# During EDA I found that in most of the columns some of the values are negative. So, I will replace it later with 0 if prediction will not give better result otherwise not.

# %%
# Replacing negative value with 0
data[data < 0] = 0

# %%
data.head(50)
# Out:
#     climbRate  Sgz     p     q  curPitch  curRoll  absRoll  diffClb  \
# 0           2    0  0.00  0.00      0.90      0.2        0       12
# 1         470    0  0.02  0.12      0.39      0.0        0        8
# 2         165    4  0.14  0.14      0.78      0.4        0        0
# 3           0    5  0.00  0.11      1.06      0.6        0        0
# 4           0    0  0.00  0.07      1.33      0.0        0        0
# 5           0    0  0.23  0.00      0.92      0.0        0       10
# 6         144    0  0.31  0.00      0.67      0.6        0        5
# 7         249    0  0.00  0.06      0.56      0.4        0        0
# 8         229    0  0.00  0.05      0.58      0.0        0        0
# 9           0   14  0.22  0.15      0.89      0.0        0        0
# 10          0    8  0.35  0.12      1.02      0.0        0        0
# 11          0    0  0.00  0.02      1.02      0.4        0        3
# 12          0    0  0.00  0.04      0.89      0.0        0        2
# 13          0    0  0.20  0.06      0.76      0.0        0        0
# 14          0    0  0.30  0.07      0.77      0.0        0        0
# 15          0    0  0.34  0.07      0.79      0.2        0        0
# 16          0    0  0.33  0.08      0.81      0.4        0        0
# 17          0    0  0.00  0.00      0.71      0.6        0        4
# 18         71    0  0.14  0.09      0.63      0.0        0        0
# 19          0    0  0.10  0.11      0.91      0.0        0        0
# 20          0    0  0.04  0.11      1.03      0.0        0        0
# 21          0    0  0.09  0.00      0.74      0.0        0       15
# SeTime8         AxesSubplot(0.223936,0.437414;0.0824468x0.130172)
# SeTime9         AxesSubplot(0.322872,0.437414;0.0824468x0.130172)
# SeTime10        AxesSubplot(0.421809,0.437414;0.0824468x0.130172)
# SeTime11        AxesSubplot(0.520745,0.437414;0.0824468x0.130172)
# SeTime12        AxesSubplot(0.619681,0.437414;0.0824468x0.130172)
# SeTime13        AxesSubplot(0.718617,0.437414;0.0824468x0.130172)
# SeTime14        AxesSubplot(0.817553,0.437414;0.0824468x0.130172)
# alpha              AxesSubplot(0.125,0.281207;0.0824468x0.130172)
# Se              AxesSubplot(0.223936,0.281207;0.0824468x0.130172)
# goal            AxesSubplot(0.322872,0.281207;0.0824468x0.130172)
# dtype: object

# %% [markdown]
# Outlier present in most of the columns.

# %%
# removing outliers
from scipy.stats import zscore
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([    4,    20,    29, ..., 12247, 12248, 12248], dtype=int64),
#  array([36, 26, 32, ...,  1,  1, 26], dtype=int64))

# %%
df_new=data[(z<3).all(axis=1)]

# %%
# Chceking null values
df_new.isnull().sum()
# Out:
# climbRate       0
# Sgz             0
# p               0
# q               0
# curPitch        0
# curRoll         0
# absRoll         0
# diffClb         0
# diffRollRate    0
# diffDiffClb     0
# SeTime1         0
# SeTime2         0
# SeTime3         0
# SeTime4         0
# SeTime5         0
# SeTime6         0
# SeTime7         0
# SeTime8         0
# SeTime9         0
# SeTime10        0
# SeTime11        0
# SeTime12        0
# SeTime13        0
# SeTime14        0
# alpha           0
# Se              0
# goal            0
# dtype: int64

# %%
# Checking Shape
df_new.shape
# Out:
# (8904, 27)

# %% [markdown]
# So, 3346 rows has been removed as a outlier.

# %% [markdown]
# # Statistical Summary

# %%
df_new.describe()
# Out:
#          climbRate          Sgz            p            q     curPitch  \
# count  8904.000000  8904.000000  8904.000000  8904.000000  8904.000000
# mean     18.210355   -12.232031     0.006936     0.050250     0.571854
# std     236.194233    24.674192     0.294694     0.103067     0.256154
# min    -787.000000   -89.000000    -0.900000    -0.280000    -0.180000
# 25%    -132.000000   -28.000000    -0.210000    -0.020000     0.400000
# 50%      11.000000   -13.000000     0.020000     0.050000     0.570000
# 75%     174.000000     4.000000     0.220000     0.120000     0.730000
# max     767.000000    64.000000     0.910000     0.410000     1.540000
#
#            curRoll      absRoll      diffClb  diffRollRate  diffDiffClb  ...  \
# count  8904.000000  8904.000000  8904.000000   8904.000000  8904.000000  ...
# mean      0.051134   -10.833109     0.061321     -0.000437    -0.074865  ...
# std       0.955262     4.022625     9.448207      0.012265     0.843497  ...
# min      -2.800000   -23.000000   -32.000000     -0.041000    -3.400000  ...
# 25%      -0.600000   -13.000000    -6.000000     -0.008000    -0.300000  ...
# 50%       0.200000   -10.000000     1.000000      0.000000    -0.100000  ...
# 75%       0.700000    -7.000000     6.000000      0.008000     0.100000  ...
# max       2.900000    -3.000000    30.000000      0.039000     3.300000  ...
#
#            SeTime8      SeTime9     SeTime10     SeTime11     SeTime12  \
# count  8904.000000  8904.000000  8904.000000  8904.000000  8904.000000
# mean      0.020997     0.020997     0.020962     0.020962     0.020941
# std       0.004927     0.004927     0.004933     0.004933     0.004932
# min       0.012000     0.012000     0.012000     0.012000     0.012000
# 25%       0.018000     0.018000     0.018000     0.018000     0.018000
# 50%       0.020000     0.020000     0.019000     0.019000     0.019000
# 75%       0.022000     0.022000     0.022000     0.022000     0.022000
# max       0.042000     0.042000     0.042000     0.042000     0.042000
#
#           SeTime13     SeTime14        alpha           Se         goal
# count  8904.000000  8904.000000  8904.000000  8904.000000  8904.000000
# mean      0.020941     0.020902     0.592644     0.020902    -0.000832
# std       0.004932     0.004930     0.140148     0.004930     0.000343
# min       0.012000     0.012000     0.400000     0.012000    -0.002000
# 25%       0.018000     0.018000     0.500000     0.018000    -0.001000
# 50%       0.019000     0.019000     0.500000     0.019000    -0.000800
# 75%       0.022000     0.022000     0.600000     0.022000    -0.000600
# max       0.042000     0.042000     1.200000     0.042000    -0.000200
#
# [8 rows x 27 columns]

# %% [markdown]
# Number of count is same in every columns.
#
# There is not much difference between mean and median(50%) in any column.
#
# There is some difference between 75% and max in some of the columns but not much.

# %% [markdown]
# # Correlation Matrix

# %%
df.corr()
# Out:
#               climbRate       Sgz         p         q  curPitch   curRoll  \
# climbRate      1.000000 -0.004769  0.162379  0.093983 -0.790573 -0.122171
# Sgz           -0.004769  1.000000  0.060038  0.339946 -0.002966 -0.000332
# p              0.162379  0.060038  1.000000  0.112880 -0.122564 -0.034589
# q              0.093983  0.339946  0.112880  1.000000  0.142712  0.035692
# curPitch      -0.790573 -0.002966 -0.122564  0.142712  1.000000  0.079088
# curRoll       -0.122171 -0.000332 -0.034589  0.035692  0.079088  1.000000
# absRoll       -0.037557  0.087779 -0.020300 -0.386417 -0.160461  0.208059
# diffClb        0.074529 -0.447481 -0.080816 -0.774364 -0.189940 -0.157744
# diffRollRate   0.159539 -0.051378  0.140791 -0.194475 -0.142244 -0.670810
# diffDiffClb   -0.330871 -0.015052 -0.123676 -0.436004  0.234823  0.028178
# SeTime1        0.094530 -0.003635  0.029970  0.346914  0.519697 -0.045408
# SeTime2        0.080349  0.002278  0.033051  0.362780  0.532706 -0.041174
# SeTime3        0.080376  0.002269  0.033066  0.362783  0.532677 -0.041179
# SeTime4        0.073132  0.005068  0.033664  0.369841  0.539249 -0.038618
# SeTime5        0.073157  0.005074  0.033690  0.369943  0.539224 -0.038608
# SeTime6        0.064980  0.006640  0.031011  0.376286  0.546932 -0.036429
# SeTime7        0.064934  0.006624  0.030899  0.376355  0.546976 -0.036389
# SeTime8        0.052460  0.006360  0.025836  0.384132  0.558616 -0.033627
# SeTime9        0.052458  0.006393  0.025864  0.384147  0.558620 -0.033635
# SeTime10       0.036596  0.006609  0.021172  0.394224  0.573154 -0.030203
# SeTime11       0.036386  0.006694  0.021109  0.394398  0.573395 -0.030029
# SeTime12       0.017863  0.006913  0.016016  0.403464  0.590264 -0.027976
# SeTime13       0.017749  0.006937  0.015966  0.403627  0.590389 -0.027969
# diffSeTime2   3.163772e-03
# diffSeTime3  -2.075079e-02
# diffSeTime4   8.893457e-03
# diffSeTime5  -1.929160e-02
# diffSeTime6   2.352422e-02
# diffSeTime7  -3.255488e-02
# diffSeTime8  -2.372519e-18
# diffSeTime9  -2.704551e-02
# diffSeTime10  1.055807e-02
# diffSeTime11 -2.934954e-02
# diffSeTime12  1.026539e-02
# diffSeTime13 -2.895375e-02
# diffSeTime14  2.140447e-02
# alpha        -6.059934e-01
# Se           -6.240510e-01
# goal          1.000000e+00
#
# [41 rows x 41 columns]

# %%
plt.figure(figsize=(50,30))
sns.heatmap(df_new.corr(),annot=True,linewidths =3,fmt='0.2f',cmap="BrBG",annot_kws={"size":30}, linecolor='Black')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Target column goal is positively correlated with absRoll and most of the columns are negatively correlated.
# climbRate is negatively correlated with curPitch.
# q is negatively correlated with diffClb.

# %%
# checking the columns which are postively and negatively correlated with target column goal
plt.figure(figsize=(22,7))
df_new.corr()['goal'].sort_values(ascending=False).drop(['goal']).plot(kind='bar')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=20)
plt.show()

# %% [markdown]
# We can see most of the columns are negatively correlated.

# %% [markdown]
# # Seprating the columns into feature and target

# %%
x=df_new.drop(['goal'],axis=1)
y=df_new['goal']

# %%
x.shape
# Out:
# (8904, 26)

# %%
y.shape
# Out:
# (8904,)

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=.25, random_state=47)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (6678, 26)
# (2226, 26)
# (6678,)
# (2226,)

# %% [markdown]
# # Model Building

# %%
# importing libraries
from sklearn.linear_model import LinearRegression ,Lasso ,Ridge ,ElasticNet
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score
from sklearn.model_selection import cross_val_score

# %%
#for Linear Regression

lr=LinearRegression()
lr.fit(x_train,y_train)
pred_y=lr.predict(x_test)
print('r2 score',r2_score(y_test,pred_y))

print('error')
print('mean absolute error', mean_absolute_error(y_test,pred_y))
print('mean squared error', mean_squared_error(y_test,pred_y))

print('root mean squared error', np.sqrt(mean_squared_error(y_test,pred_y)))
# Out:
# r2 score 0.8132261726449959
# error
# mean absolute error 0.00011421055273797557
# mean squared error 2.2222249620685758e-08
# root mean squared error 0.00014907129039719807

# %%
# For Linear Regression (cross validation)


score=cross_val_score(lr,x,y,cv=10)
print('cv score',np.mean(score))
# Out:
# cv score 0.7897453784296816

# %% [markdown]
# So Linear Regreesion is giving very less errors and 81% r2 score and 78% cross validation score.

# %%
# Linear Regression
# graph showing the performance of the model
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=pred_y, color='b')
plt.plot(y_test,y_test, color='r')
plt.xlabel('actual',fontsize=14)
plt.ylabel('predicted',fontsize=18)
plt.show()

# %% [markdown]
# Best Fit Line is covering most of the data points.

# %%
# for Lasso

ls=Lasso()

ls.fit(x_train,y_train)
pred_y=ls.predict(x_test)
print('r2 score',r2_score(y_test,pred_y))

print('error')
print('mean absolute error', mean_absolute_error(y_test,pred_y))
print('mean squared error', mean_squared_error(y_test,pred_y))

print('root mean squared error', np.sqrt(mean_squared_error(y_test,pred_y)))
# Out:
# r2 score -0.0001684913243731323
# error
# mean absolute error 0.00027815789976447046
# mean squared error 1.1899950968349313e-07
# root mean squared error 0.0003449630555342023

# %%
# For Lasso (cross validation)


score=cross_val_score(ls,x,y,cv=10)
print('cv score',np.mean(score))
# Out:
# cv score -0.13469922676623178

# %% [markdown]
# So errors are very less from Lasso Regularization but r2 score and cross validation score are not good.

# %%
# Lasso
# graph showing the performance of the model
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=pred_y, color='b')
plt.plot(y_test,y_test, color='r')
plt.xlabel('actual',fontsize=14)
plt.ylabel('predicted',fontsize=18)
plt.show()

# %% [markdown]
# Best fit line is covering most of the data points.

# %%
#For Ridge

rd=Ridge()

rd.fit(x_train,y_train)
pred_y=rd.predict(x_test)
print('r2 score',r2_score(y_test,pred_y))

print('error')
print('mean absolute error', mean_absolute_error(y_test,pred_y))
print('mean squared error', mean_squared_error(y_test,pred_y))

print('root mean squared error', np.sqrt(mean_squared_error(y_test,pred_y)))
# Out:
# r2 score 0.8081916142120733
# error
# mean absolute error 0.00011592569891885066
# mean squared error 2.2821258677847082e-08
# root mean squared error 0.00015106706682082327

# %%
# For Ridge (cross  validation)


score=cross_val_score(rd,x,y,cv=10)
print('cv score',np.mean(score))
# Out:
# cv score 0.7844387506842282

# %% [markdown]
# From Ridge Regularization, errors are very less and r2 score is 80% and cv score is 78%.

# %%
# ridge
# graph showing the performance of the model
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=pred_y, color='b')
plt.plot(y_test,y_test, color='r')
plt.xlabel('actual',fontsize=14)
plt.ylabel('predicted',fontsize=18)
plt.show()

# %% [markdown]
# Best Fit line is covering most of the datapoints.

# %%
#For ElasticNet



en=ElasticNet()

en.fit(x_train,y_train)
pred_y=en.predict(x_test)
print('r2 score',r2_score(y_test,pred_y))

print('error')
print('mean absolute error', mean_absolute_error(y_test,pred_y))
print('mean squared error', mean_squared_error(y_test,pred_y))

print('root mean squared error', np.sqrt(mean_squared_error(y_test,pred_y)))
# Out:
# r2 score -0.0001684913243731323
# error
# mean absolute error 0.00027815789976447046
# mean squared error 1.1899950968349313e-07
# root mean squared error 0.0003449630555342023

# %%
#For ElasticNet (cross validation)

score=cross_val_score(en,x,y,cv=10)
print('cv score',np.mean(score))
# Out:
# cv score -0.13469922676623178

# %% [markdown]
# Erros are less and r2 score and cross validation scores are not good.

# %%
# elasicnet
# graph showing the performance of the model
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=pred_y, color='b')
plt.plot(y_test,y_test, color='r')
plt.xlabel('actual',fontsize=14)
plt.ylabel('predicted',fontsize=18)
plt.show()

# %% [markdown]
# Best fit Line is covering most of the data points.

# %% [markdown]
# So, from the training and predcitions from above algorithms we can say that our every model is performing well because errors are very less from MAE, MSE and RMSE, now will do hyper parameter tunning for better prediction.

# %% [markdown]
# # Hyper Parameter Tuning using Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion='mse',max_features='auto')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)
print('root mean squared error', np.sqrt(mean_squared_error(y_test,pred_decision)))
# Out:
# root mean squared error 0.00014789835725614262

# %% [markdown]
# # Model Saving

# %%
import pickle
filename='ailerons.pkl'
pickle.dump(rf, open(filename, 'wb'))

# %% [markdown]
# # Conclusion

# %% [markdown]
# So after EDA, Preprocessing, Outlier Removal, Model training and building and last after prediction we are getting very less error and we can say that our model is performing extremly well and we can deploy it for future.
