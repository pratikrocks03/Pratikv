# %%
import requests
import json
import regex as re

# %%
header = {
  'Connection': 'keep-alive',
  'sec-ch-ua': '"Chromium";v="92", " Not A;Brand";v="99", "Google Chrome";v="92"',
  'X-User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36 FKUA/website/42/website/Desktop',
  'sec-ch-ua-mobile': '?0',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36',
  'Content-Type': 'application/json',
  'Accept': '*/*',
  'Origin': 'https://www.flipkart.com',
  'Sec-Fetch-Site': 'same-site',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Dest': 'empty',
  'Referer': 'https://www.flipkart.com/',
  'Accept-Language': 'en-US,en;q=0.9',
  'Cookie': 'T=TI162556940033200100877545069827913751709558665212030031070223007111; _pxvid=c8b687b8-de49-11eb-b952-0242ac12000e; AMCVS_17EB401053DAF4840A490D4C%40AdobeOrg=1; AMCV_17EB401053DAF4840A490D4C%40AdobeOrg=-227196251%7CMCIDTS%7C18864%7CMCMID%7C07296285264556587020499017255201469320%7CMCAAMLH-1630393051%7C12%7CMCAAMB-1630393051%7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y%7CMCOPTOUT-1629795451s%7CNONE%7CMCAID%7CNONE; s_cc=true; pxcts=8ef15440-04a8-11ec-a25f-55d83f2f67ee; Network-Type=4g; gpv_pn=Product%20Page; gpv_pn_t=FLIPKART%3AProduct%20Page; SN=VI22BF1C73ED604153BF6B2506A55699DB.TOKFE5C2ACFE1EA45CF8B69CF234A5EBC3C.1629788439.LO; S=d1t19Kz9jSj8/P0VGZGJZP2c/P+ZY1pVv2c2FdiqZDHX2bVWwqaTSJ27V5+F9NYaPQQhH8lqls8bPCHA9BO9lcmaUug==; _px3=959b312200b027861295c428eb15235382ae2465d05340384dd1f55c5fb36ccb:tRasWa+WsxyC74zRwPoNdan35612sxdLNJ+fnF3RKFAp/RBQ3MWX98SBY6c1ucdVsNxKvbkzarQoN+MQOnWe5g==:1000:cIRE4nak/sHEmAjSpIP6SU+X3vc2chn5H17sPfIUVJNJZjdamg1/PuNsedmWxhqEe3yWv8kwSd/Z+lVZx5OUOxGvj4KepmiRhcBUxCQfPbC5mjzrypCFIifu8lpFmsQXR2azp+RJcpyf9neWuHurKDLDrsBzI0mRcXCZBMiWldqMbhhl0kBWmNyFndUK+QqancuBfLTmWfFKoL4j1bV5yw==; s_sq=%5B%5BB%5D%5D; S=d1t18P0lxPz8/Nlk/Pz8/CD8/fKB9OxerwgUZGXO4VXWy+leRHJGRlEAo7lb65Iu/p7Y90Wgkh9aLTagQiRu2+WBc9Q==; SN=VID86B075FFD5A47C991A18D6EBA85ED93.TOKD08C62AAC57D4CD6B26EDEF0E518FC1F.1629788566.LO'
}

# %%
headers = {
  'Connection': 'keep-alive',
  'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="98", "Google Chrome";v="98"',
  'X-User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36 FKUA/website/42/website/Desktop',
  'Content-Type': 'application/json',
  'sec-ch-ua-mobile': '?0',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.102 Safari/537.36',
  'sec-ch-ua-platform': '"Windows"',
  'Accept': '*/*',
  'Origin': 'https://www.flipkart.com',
  'Sec-Fetch-Site': 'same-site',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Dest': 'empty',
  'Referer': 'https://www.flipkart.com/',
  'Accept-Language': 'en-US,en;q=0.9,de;q=0.8',
  'Cookie': 'T=TI164621653648100142510124718994283005100198161941622646527677026518; Network-Type=4g; pxcts=a3d8377e-9a12-11ec-b71d-4c42794f666e; _pxvid=a3d82b99-9a12-11ec-b71d-4c42794f666e; AMCVS_17EB401053DAF4840A490D4C%40AdobeOrg=1; AMCV_17EB401053DAF4840A490D4C%40AdobeOrg=-227196251%7CMCIDTS%7C19054%7CMCMID%7C87052282055796705313563068860917978786%7CMCAAMLH-1646821022%7C12%7CMCAAMB-1646821022%7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y%7CMCOPTOUT-1646223423s%7CNONE%7CMCAID%7CNONE; s_sq=flipkart-prd%3D%2526pid%253Dwww.flipkart.com%25253A%2526pidt%253D1%2526oid%253Dhttps%25253A%25252F%25252Fwww.flipkart.com%25252Fsearch%25253Fq%25253Dmortein%252526otracker%25253Dsearch%252526otracker1%25253Dsearch%252526marketplace%25253DFLIPKART%252526as-s%2526ot%253DA; S=d1t12Pz9NP3Q/fz8QPz8/Pz8/XpfZ0jAn1TjbCQVdeSIb/QEi7fL1Z38f44XRC0XAD3QeIu1KUux2VTQIGYTX7AYLTg==; _px3=6149d6d69fa77edeb22ec632d0a66ecf7249d09eb177c272403cd32930f36160:3+ofi5W1ZMuvtcTiTm29jFWnsqlm12Nwef0KuuDx3mCBgpw3BOnkwl394OLB+f+o9I7XCWprOJIB6pqcHoN0+g==:1000:F4IW80crXCaujNWHs+exSHJPAg1+rWVRJB7T/6eHBzU3S9Ym1gQZCudCmqDRFMKtceHsvDE06XsGrVl6oYEj47XkrbvKsuTl2AxFmc96p7dQhoy0kU2z4t2E6WyeYFN4hzYe5+50/Y9nnTEcDfpJv4L35WK09Qe0XN9+rlBCN6BJ+d0vPCjmTsyHRaY7353JNTEtYZdfOtC5dnDeRlEQHg==; SN=VI87DC79BA3C5C4A6E9808FF86AAB1D96F.TOK1D35676E7D0A4A26A38D864093E8E138.1646224252.LO; S=d1t12CD8/PyE/Ahw/NT9qPx4rPwrRmwCbH/+HAv9HbsDrzirjXeIKgzjd3n3SKMxsx0DgrW2ajpwORT82QFCkXRqXDA==; SN=VI87DC79BA3C5C4A6E9808FF86AAB1D96F.TOK1D35676E7D0A4A26A38D864093E8E138.1646224252.LO'
}

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

# %%
ID=[]
itemID=[]
listingID=[]
productname=[]
for i in range(1,3):
    url = "https://1.rome.api.flipkart.com/api/4/page/fetch"

    payload = json.dumps({
      "pageUri": "/search?q=mortein&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={}".format(i),
      "pageContext": {
        "fetchSeoData": True,
        "paginatedFetch": True,
        "pageNumber": 1,
        "paginationContextMap": {
          "federator": {
            "FILTER_NAVIGATION": 1,
            "productsOffset": 46,
            "pageNumber": 2,
            "FILTER_TAB": 0,
            "AUGMENTATION_CARD": 0,
            "INLINE_GUIDE": 0,
            "MESSAGING_CARD": 0,
            "SERVICEABILITY_FILTER": 0,
            "ANNOUNCEMENTS_NAVIGATION": 0,
            "INLINE_VISUAL_CARD": 0,
            "CATEGORY_TREE": 0,
            "feedbackMap": {},
            "SERVICEABILITY_CARD": 0,
            "ADS": 0,
            "MERCH_CARD": 0,
            "PAGINATION_BAR": 1,
            "CATEGORY_VALUES": 0,
            "FILTER_SORT_OPTIONS": 1,
            "PRODUCT": 46,
            "priceSortSlots": [],
            "SHOP_CARD": 0,
            "redirection.store.path": "search.flipkart.com",
            "topAds": 0,
            "CLEAR_FILTERS": 0,
            "EMPTY_SEARCH": 1,
            "OFFER_HEADER_CARD": 0,
            "widgetOffset": 43,
            "FILTER_FOOTER": 0,
            "widgetStart": 42,
            "store.path": "search.flipkart.com",
            "PLA_GROUP_CARD": 0,
            "layout": "grid",
            "COMPARE_OPTIONS": 0,
            "productsEnd": 0,
            "droppedContents": {
              "skippedAdsHashSet": []
            },
            "INLINE_FILTER": 0,
            "SHOP_PRODUCT_CARD": 0,
            "FILTER_VALUES": 0,
            "MULTI_CONTENT_CARD": 0,
            "SEARCH_FEEDBACK_CARD": 1,
            "productTypeClusterStart": 47
          }
        }
      },
      "requestContext": {
        "type": "BROWSE_PAGE",
        "ssid": "enwzojbyzk0000001646223930650",
        "sqid": "wouxr0dx340000001646223959988"
      }
    })
    response = requests.request("POST", url, headers=headers, data=payload)
    print(response.text)

    data=json.loads(response.text)
    #print(data)
    data=data['RESPONSE']
    print(data)
    #print(data)
    data=data['slots']
    for j in data:
        try:
            data=j['widget']
            data=data['data']
            data=data['products']
            for i in data:
                data2=i['productInfo']
                #data2=data2['action']
                data2=data2['value']
                data3=data2['titles']
                productname.append(data3['title'])
                itemID.append(data2['itemId'])
                listingID.append(data2['listingId'])
                ID.append(data2['id'])
        except:
            continue
# Out:
# <html>
# <head><title>504 Gateway Time-out</title></head>
# <body>
# <center><h1>504 Gateway Time-out</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Input In [5], in <cell line: 5>()
#      68 response = requests.request("POST", url, headers=headers, data=payload)
#      69 print(response.text)
# ---> 71 data=json.loads(response.text)
#      72 #print(data)
#      73 data=data['RESPONSE']
#
# File ~\Anaconda3\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# ...

# %%
'''ID=[]
itemID=[]
listingID=[]
productname=[]
for i in range(1,3):
    url = "https://1.rome.api.flipkart.com/api/4/page/fetch"

    payload = json.dumps({
      "pageUri": "/search?q=harpic&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={}".format(i),
      "pageContext": {
        "fetchSeoData": True,
        "paginatedFetch": True,
        "pageNumber": 2,
        "paginationContextMap": {
          "federator": {
            "FILTER_NAVIGATION": 0,
            "productsOffset": 35,
            "pageNumber": 1,
            "FILTER_TAB": 0,
            "AUGMENTATION_CARD": 0,
            "INLINE_GUIDE": 0,
            "MESSAGING_CARD": 0,
            "SERVICEABILITY_FILTER": 0,
            "ANNOUNCEMENTS_NAVIGATION": 0,
            "INLINE_VISUAL_CARD": 0,
            "CATEGORY_TREE": 0,
            "feedbackMap": {},
            "SERVICEABILITY_CARD": 0,
            "ADS": 5,
            "MERCH_CARD": 0,
            "PAGINATION_BAR": 1,
            "CATEGORY_VALUES": 0,
            "FILTER_SORT_OPTIONS": 1,
            "PRODUCT": 35,
            "priceSortSlots": [],
            "redirection.store.path": "rja",
            "topAds": 2,
            "CLEAR_FILTERS": 0,
            "EMPTY_SEARCH": 1,
            "OFFER_HEADER_CARD": 0,
            "widgetOffset": 11,
            "FILTER_FOOTER": 0,
            "widgetStart": 10,
            "store.path": "search.flipkart.com",
            "PLA_GROUP_CARD": 0,
            "layout": "grid",
            "COMPARE_OPTIONS": 0,
            "droppedContents": {
              "skippedAdsHashSet": [
                {
                  "listingId": "LSTTCNFZC8MHNRFFEFPMWIKWB",
                  "skippedReason": "DEDUPE"
                }
              ]
            },
            "INLINE_FILTER": 0,
            "FILTER_VALUES": 0,
            "MULTI_CONTENT_CARD": 0,
            "SEARCH_FEEDBACK_CARD": 1,
            "productTypeClusterStart": 41
          }
        }
      },
      "requestContext": {
        "type": "BROWSE_PAGE",
        "ssid": "zg3ta6ui5s0000001619683961970",
        "sqid": "pkc8q6xnpc0000001619684692987"
      }
    })

    response = requests.request("POST", url, headers=headers, data=payload)
    #print(response)

    data=json.loads(response.text)
    print(data)
    data=data['RESPONSE']
    print(data)
    data=data['slots']
    for j in data:
        try:
            data=j['widget']
            data=data['data']
            data=data['products']
            for i in data:
                data2=i['productInfo']
                #data2=data2['action']
                data2=data2['value']
                data3=data2['titles']
                productname.append(data3['title'])
                itemID.append(data2['itemId'])
                listingID.append(data2['listingId'])
                ID.append(data2['id'])
        except:
            continue
    

    
 '''

# %%
itemID = [each_string.lower() for each_string in itemID]

# %%
print(len(productname))
print(len(itemID))
print(len(ID))
print(len(listingID))
# Out:
# 0
# 0
# 0
# 0

# %%
import pandas as pd

# %%
for i in productname:
    print(i)

# %%
#df_main=[]

# %%
#df_main=pd.DataFrame()

# %%
allid=[]
allpn=[]
alld=[]
allr=[]
allt=[]
allre=[]
for p,q,z,s in zip(itemID,ID,listingID,productname):
    for i in range(1,15):
        
        url = "https://1.rome.api.flipkart.com/api/4/page/fetch"

        payload = json.dumps({
          "pageUri": "/vanish-oxi-action-pack-2-multi-fragrance-liquid-detergent/product-reviews/{}?pid={}&lid={}&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT&page={}".format(p,q,z,i),
          "pageContext": {
            "fetchSeoData": True
          }
        })
        headers = {
          'Connection': 'keep-alive',
          'sec-ch-ua': '"Chromium";v="92", " Not A;Brand";v="99", "Google Chrome";v="92"',
          'X-User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36 FKUA/website/42/website/Desktop',
          'sec-ch-ua-mobile': '?0',
          'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36',
          'Content-Type': 'application/json',
          'Accept': '*/*',
          'Origin': 'https://www.flipkart.com',
          'Sec-Fetch-Site': 'same-site',
          'Sec-Fetch-Mode': 'cors',
          'Sec-Fetch-Dest': 'empty',
          'Referer': 'https://www.flipkart.com/',
          'Accept-Language': 'en-US,en;q=0.9',
          'Cookie': 'T=TI162556940033200100877545069827913751709558665212030031070223007111; _pxvid=c8b687b8-de49-11eb-b952-0242ac12000e; AMCVS_17EB401053DAF4840A490D4C%40AdobeOrg=1; AMCV_17EB401053DAF4840A490D4C%40AdobeOrg=-227196251%7CMCIDTS%7C18864%7CMCMID%7C07296285264556587020499017255201469320%7CMCAAMLH-1630393051%7C12%7CMCAAMB-1630393051%7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y%7CMCOPTOUT-1629795451s%7CNONE%7CMCAID%7CNONE; s_cc=true; pxcts=8ef15440-04a8-11ec-a25f-55d83f2f67ee; Network-Type=4g; SN=VI22BF1C73ED604153BF6B2506A55699DB.TOKFE5C2ACFE1EA45CF8B69CF234A5EBC3C.1629790574.LO; _px3=383b36a8c46f66b79b58a2f661234820ef605acb38de6354a655ab7b9c024f31:0QXnOzbhH9aqMtZUIMm/slEcn4ct8CPj3YlTwXgpX6zODNyR7/J9vHKXAgz2JQdtlOFNENAPb6nJqjpFR5nSBQ==:1000:2jWetdc97mBcqDmOxDONokVz2JvNC600QtE7zTRo4F1AVvN+8Ke4KdkkRE/pI8+cg5A3Bt3kxnHWtBP/fyh4YRDptHQwaaB/StJpEqyigJOtuMRJs7RrQWemDeXgSliKHlsbcv44xetpbxOCf1qrhPogpkHJIxf2BQETdDER+ZKZHxCOTUYW9Yey/u8pCmYcIfpPSelK1c8rQMx8ee5Xaw==; gpv_pn=Read%20Review%3A%20Vanish%20Oxi%20Action%20%28Pack%20of%202%29%20Multi-Fragrance%20Liquid%20Detergent; gpv_pn_t=Read%20Review; S=d1t19PzFhPz8/Pz8/dyY/P18/P3/YWLwdFV5GAaCVkq4US/zepIjxZlF39Gppi+Zg65wYR3ar08HOclrzDH4rRyb+qg==; s_sq=flipkart-prd%3D%2526pid%253DRead%252520Review%25253A%252520Vanish%252520Oxi%252520Action%252520%252528Pack%252520of%2525202%252529%252520Multi-Fragrance%252520Liquid%252520Detergent%2526pidt%253D1%2526oid%253Dhttps%25253A%25252F%25252Fwww.flipkart.com%25252Fvanish-oxi-action-pack-2-multi-fragrance-liquid-detergent%25252Fproduct-reviews%25252Fi%2526ot%253DA; S=d1t18Gxg/Pz8/P3dtPy8/GRs/MBLzTLUafdOMDiGzd7VTnFzrdt+DR0lgfnbo2Ad4TgB2OFBdxYn5LSB3BzWA61bLSQ==; SN=VID86B075FFD5A47C991A18D6EBA85ED93.TOKD08C62AAC57D4CD6B26EDEF0E518FC1F.1629790468.LO'
        }

        response = requests.request("POST", url, headers=header, data=payload)

        data=json.loads(response.text)
        data=data['RESPONSE']
        data=data['slots']
        for j in data:
            #print("yes")
            try:
                data=j['widget']
                
                data=data['data']
                data=data['renderableComponents']
                for i in data:
                    data=i['value']
                    alld.append(data['created'])
                    allid.append(data['id'])
                    allr.append(data['rating'])
                    allt.append(data['title'])
                    allre.append(data['text'])
                    allpn.append(s)
                    a={'ID':allid,'Product Name':allpn,'Date':alld,'Title':allt,'Review':allre,'Rating':allr}
                    output=pd.DataFrame.from_dict(a, orient='index')
                    output=output.transpose()

                    
                    #df2=pd.DataFrame([[allid,allpn,alld,allt,allre,allr]],columns=['Review ID','Product Name','Date','Title','Review','Rating'])
                    df_main=df_main.append(output,ignore_index=True)
                    allid=[]
                    allpn=[]
                    alld=[]
                    allr=[]
                    allt=[]
                    allre=[]
                    output=[]
                    
            except:
                continue

# %%
allid=[]
allpn=[]
alld=[]
allr=[]
allt=[]
allre=[]
for p,q,z,s in zip(itemID,ID,listingID,productname):
    for i in range(1,15):
        
        url = "https://1.rome.api.flipkart.com/api/4/page/fetch"

        payload = json.dumps({
          "pageUri": "/harpic-bleach-white-shine-original-regular-gel-toilet-cleaner/product-reviews/{}?pid={}&lid={}&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT&page={}".format(p,q,z,i),
          "pageContext": {
            "fetchSeoData": True
          }
        })
        headers = {
          'Connection': 'keep-alive',
          'sec-ch-ua': '"Chromium";v="92", " Not A;Brand";v="99", "Google Chrome";v="92"',
          'X-User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36 FKUA/website/42/website/Desktop',
          'sec-ch-ua-mobile': '?0',
          'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36',
          'Content-Type': 'application/json',
          'Accept': '*/*',
          'Origin': 'https://www.flipkart.com',
          'Sec-Fetch-Site': 'same-site',
          'Sec-Fetch-Mode': 'cors',
          'Sec-Fetch-Dest': 'empty',
          'Referer': 'https://www.flipkart.com/',
          'Accept-Language': 'en-US,en;q=0.9',
          'Cookie': 'T=TI162556940033200100877545069827913751709558665212030031070223007111; _pxvid=c8b687b8-de49-11eb-b952-0242ac12000e; AMCVS_17EB401053DAF4840A490D4C%40AdobeOrg=1; AMCV_17EB401053DAF4840A490D4C%40AdobeOrg=-227196251%7CMCIDTS%7C18864%7CMCMID%7C07296285264556587020499017255201469320%7CMCAAMLH-1630393051%7C12%7CMCAAMB-1630393051%7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y%7CMCOPTOUT-1629795451s%7CNONE%7CMCAID%7CNONE; s_cc=true; pxcts=8ef15440-04a8-11ec-a25f-55d83f2f67ee; Network-Type=4g; gpv_pn=Product%20Page; gpv_pn_t=FLIPKART%3AProduct%20Page; SN=VI22BF1C73ED604153BF6B2506A55699DB.TOKFE5C2ACFE1EA45CF8B69CF234A5EBC3C.1629788439.LO; S=d1t19Kz9jSj8/P0VGZGJZP2c/P+ZY1pVv2c2FdiqZDHX2bVWwqaTSJ27V5+F9NYaPQQhH8lqls8bPCHA9BO9lcmaUug==; _px3=959b312200b027861295c428eb15235382ae2465d05340384dd1f55c5fb36ccb:tRasWa+WsxyC74zRwPoNdan35612sxdLNJ+fnF3RKFAp/RBQ3MWX98SBY6c1ucdVsNxKvbkzarQoN+MQOnWe5g==:1000:cIRE4nak/sHEmAjSpIP6SU+X3vc2chn5H17sPfIUVJNJZjdamg1/PuNsedmWxhqEe3yWv8kwSd/Z+lVZx5OUOxGvj4KepmiRhcBUxCQfPbC5mjzrypCFIifu8lpFmsQXR2azp+RJcpyf9neWuHurKDLDrsBzI0mRcXCZBMiWldqMbhhl0kBWmNyFndUK+QqancuBfLTmWfFKoL4j1bV5yw==; s_sq=%5B%5BB%5D%5D; S=d1t18P0lxPz8/Nlk/Pz8/CD8/fKB9OxerwgUZGXO4VXWy+leRHJGRlEAo7lb65Iu/p7Y90Wgkh9aLTagQiRu2+WBc9Q==; SN=VID86B075FFD5A47C991A18D6EBA85ED93.TOKD08C62AAC57D4CD6B26EDEF0E518FC1F.1629788566.LO'
        }

        response = requests.request("POST", url, headers=headers, data=payload)

        data=json.loads(response.text)
        data=data['RESPONSE']
        data=data['slots']
        for j in data:
            #print("yes")
            try:
                data=j['widget']
                
                data=data['data']
                data=data['renderableComponents']
                for i in data:
                    data=i['value']
                    alld.append(data['created'])
                    allid.append(data['id'])
                    allr.append(data['rating'])
                    allt.append(data['title'])
                    allre.append(data['text'])
                    allpn.append(s)
                    a={'ID':allid,'Product Name':allpn,'Date':alld,'Title':allt,'Review':allre,'Rating':allr}
                    output=pd.DataFrame.from_dict(a, orient='index')
                    output=output.transpose()

                    
                    #df2=pd.DataFrame([[allid,allpn,alld,allt,allre,allr]],columns=['Review ID','Product Name','Date','Title','Review','Rating'])
                    df_main=df_main.append(output,ignore_index=True)
                    allid=[]
                    allpn=[]
                    alld=[]
                    allr=[]
                    allt=[]
                    allre=[]
                    output=[]
                    
            except:
                continue

# %%
df_main['Product Name'][1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 df_main['Product Name'][1]
#
# NameError: name 'df_main' is not defined

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            118 non-null    object
#  1   Product Name  118 non-null    object
#  2   Date          118 non-null    object
#  3   Title         118 non-null    object
#  4   Review        118 non-null    object
#  5   Rating        118 non-null    object
# dtypes: object(6)
# memory usage: 5.7+ KB

# %%
df_main.to_excel("Mortein Flipkart Sept Trial.xlsx")

# %%
df_main=pd.read_excel("MorteinAugTrial.xlsx","Sheet3")

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            7 non-null      object
#  1   Product Name  7 non-null      object
#  2   Date          7 non-null      object
#  3   Title         7 non-null      object
#  4   Review        7 non-null      object
#  5   Rating        7 non-null      int64
# dtypes: int64(1), object(5)
# memory usage: 464.0+ bytes

# %%
import datefinder

# %%
import regex as re

# %%
from dateutil.relativedelta import relativedelta

# %%
from dateutil.relativedelta import relativedelta
from datetime import datetime

# %%
def date(a):
    matches = datefinder.find_dates(a)
    for match in matches:
          return match

# %%
def ago_do_date(ago):
    value, unit = re.search(r'(\d+) (\w+) ago', ago).groups()
    if not unit.endswith('s'):
        unit += 's'
    delta = relativedelta(**{unit: int(value)})
    x=datetime.now() - delta
    print(datetime.now() - delta)
    return x

# %%
ago_do_date("10 months ago")
# Out:
# 2020-11-13 12:29:02.322390
# datetime.datetime(2020, 11, 13, 12, 29, 2, 322390)

# %%
df_main['Date2']=df_main['Date'].apply(ago_do_date)
# Out:
# 2021-08-21 12:29:09.576697
# 2021-08-18 12:29:09.577695
# 2021-08-15 12:29:09.577695
# 2021-08-29 12:29:09.577695
# 2021-08-13 12:29:09.577695
# 2021-08-30 12:29:09.578691
# 2021-08-13 12:29:09.578691

# %%
df_main['Date2'].isnull().sum()
# Out:
# 0

# %%
df_main
# Out:
#                                      ID  \
# 0  a4d14585-5a81-4aae-8a85-2d3cb5190152
# 1  b4f33a3d-df90-4b10-abda-0427868ef640
# 2  61cea289-e0df-4725-a56d-742b256c238d
# 3  ae159b4e-916b-4662-a905-ca8a2a71b8a8
# 4  c861756e-91bd-453e-952b-44e5b3273f29
# 5  2915081e-71a0-429a-856f-d22981764255
# 6  f8de2e87-b0ab-484e-8917-8071dd3d3d42
#
#                                    Product Name         Date  \
# 0             MORTEIN Insta5 Mosquito Vaporiser  23 days ago
# 1              MORTEIN RAT KILL CAKE (2 x 100g)  26 days ago
# 2              MORTEIN RAT KILL CAKE (2 x 100g)  29 days ago
# 3                         MORTEIN RAT KILL CAKE  15 days ago
# 4                         MORTEIN RAT KILL CAKE  1 month ago
# 5             MORTEIN Mosquito Vaporiser Refill  14 days ago
# 6  Mortien mortien123 Mosquito Vaporiser Refill  1 month ago
#
#                   Title                                             Review  \
# ...

# %%
df_main['Date2'] = pd.to_datetime(df_main.Date2, format='%Y-%m-%d')

# %%
df_main.head()
# Out:
#                                      ID                       Product Name  \
# 0  a4d14585-5a81-4aae-8a85-2d3cb5190152  MORTEIN Insta5 Mosquito Vaporiser
# 1  b4f33a3d-df90-4b10-abda-0427868ef640   MORTEIN RAT KILL CAKE (2 x 100g)
# 2  61cea289-e0df-4725-a56d-742b256c238d   MORTEIN RAT KILL CAKE (2 x 100g)
# 3  ae159b4e-916b-4662-a905-ca8a2a71b8a8              MORTEIN RAT KILL CAKE
# 4  c861756e-91bd-453e-952b-44e5b3273f29              MORTEIN RAT KILL CAKE
#
#           Date                 Title  \
# 0  23 days ago                Super!
# 1  26 days ago             Fabulous!
# 2  29 days ago             Brilliant
# 3  15 days ago              Horrible
# 4  1 month ago  Utterly Disappointed
#
#                                               Review  Rating  \
# 0                  Good product, thank you Flipkart.       5
# 1                                     Value of money       5
# 2                                    Value for money       5
# ...

# %%
df_main = df_main[df_main['Date2'].dt.month == 8]

# %%
df_main=df_main[df_main['Date2'].dt.year == 2021]

# %%
df_main
# Out:
#                                      ID  \
# 0  a4d14585-5a81-4aae-8a85-2d3cb5190152
# 1  b4f33a3d-df90-4b10-abda-0427868ef640
# 2  61cea289-e0df-4725-a56d-742b256c238d
# 3  ae159b4e-916b-4662-a905-ca8a2a71b8a8
# 4  c861756e-91bd-453e-952b-44e5b3273f29
# 5  2915081e-71a0-429a-856f-d22981764255
# 6  f8de2e87-b0ab-484e-8917-8071dd3d3d42
#
#                                    Product Name         Date  \
# 0             MORTEIN Insta5 Mosquito Vaporiser  23 days ago
# 1              MORTEIN RAT KILL CAKE (2 x 100g)  26 days ago
# 2              MORTEIN RAT KILL CAKE (2 x 100g)  29 days ago
# 3                         MORTEIN RAT KILL CAKE  15 days ago
# 4                         MORTEIN RAT KILL CAKE  1 month ago
# 5             MORTEIN Mosquito Vaporiser Refill  14 days ago
# 6  Mortien mortien123 Mosquito Vaporiser Refill  1 month ago
#
#                   Title                                             Review  \
# ...

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 0 to 6
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            7 non-null      object
#  1   Product Name  7 non-null      object
#  2   Date          7 non-null      object
#  3   Title         7 non-null      object
#  4   Review        7 non-null      object
#  5   Rating        7 non-null      int64
#  6   Date2         7 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 448.0+ bytes

# %%
df_main.to_excel("Mortein Flipkart August Scrape.xlsx")
